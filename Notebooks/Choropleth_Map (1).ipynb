# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import plotly.express as px
from datetime import datetime

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
play_store_df = pd.read_csv(r"C:\Users\ADMIN\OneDrive\Desktop\Google_Play_Store_Internship_Project\Data\Play Store Data.csv")

# %%
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
reviews_df = pd.read_csv(r"C:\Users\ADMIN\OneDrive\Desktop\Google_Play_Store_Internship_Project\Data\User Reviews.csv")
reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
play_store_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
reviews_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='str')

# %%
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
reviews_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
play_store_df = play_store_df[play_store_df["Installs"] != "Free"]
play_store_df["Installs_Num"] = (

    play_store_df["Installs"]
    .str.replace(",", "", regex=False)
    .str.replace("+", "", regex=False)
    .astype(float)

)

# %%
play_store_df[["Installs", "Installs_Num"]].head()
# Out:
#       Installs  Installs_Num
# 0      10,000+       10000.0
# 1     500,000+      500000.0
# 2   5,000,000+     5000000.0
# 3  50,000,000+    50000000.0
# 4     100,000+      100000.0

# %%
play_store_df = play_store_df.dropna(subset=["Installs_Num"])

# %%
play_store_df["Installs_Num"].isnull().sum()
# Out:
# np.int64(0)

# %%
play_store_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  str
#  1   Category        10840 non-null  str
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  str
#  4   Size            10840 non-null  str
#  5   Installs        10840 non-null  str
#  6   Type            10839 non-null  str
#  7   Price           10840 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10840 non-null  str
#  10  Last Updated    10840 non-null  str
#  11  Current Ver     10832 non-null  str
#  12  Android Ver     10838 non-null  str
#  13  Installs_Num    10840 non-null  float64
# dtypes: float64(2), str(12)
# memory usage: 2.3 MB

# %%
merged_df = pd.merge(play_store_df, reviews_df, on='App', how='inner')

# %%
merged_df.head()
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  Installs_Num  \
# 0       2.0.0  4.0.3 and up      500000.0
# 1       2.0.0  4.0.3 and up      500000.0
# 2       2.0.0  4.0.3 and up      500000.0
# 3       2.0.0  4.0.3 and up      500000.0
# 4       2.0.0  4.0.3 and up      500000.0
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# 1                                         It bad >:(  Negative
# 2                                               like   Neutral
# 3                                                NaN       NaN
# 4                           I love colors inspyering  Positive
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0              -0.250                1.000000
# 1              -0.725                0.833333
# 2               0.000                0.000000
# 3                 NaN                     NaN
# 4               0.500                0.600000

# %%
merged_df.shape
# Out:
# (122662, 18)

# %%
merged_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Installs_Num', 'Translated_Review', 'Sentiment',
#        'Sentiment_Polarity', 'Sentiment_Subjectivity'],
#       dtype='str')

# %%
merged_df["Category"].unique()
# Out:
# <ArrowStringArray>
# [     'ART_AND_DESIGN',   'AUTO_AND_VEHICLES',              'BEAUTY',
#  'BOOKS_AND_REFERENCE',            'BUSINESS',              'COMICS',
#        'COMMUNICATION',              'DATING',           'EDUCATION',
#        'ENTERTAINMENT',              'EVENTS',             'FINANCE',
#       'FOOD_AND_DRINK',  'HEALTH_AND_FITNESS',      'HOUSE_AND_HOME',
#   'LIBRARIES_AND_DEMO',           'LIFESTYLE',                'GAME',
#               'FAMILY',             'MEDICAL',              'SOCIAL',
#             'SHOPPING',         'PHOTOGRAPHY',              'SPORTS',
#     'TRAVEL_AND_LOCAL',               'TOOLS',     'PERSONALIZATION',
#         'PRODUCTIVITY',           'PARENTING',             'WEATHER',
#        'VIDEO_PLAYERS',  'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION']
# Length: 33, dtype: str

# %%
filtered_df = merged_df[

    ~merged_df["Category"].str.startswith(
        ("A", "C", "G", "S"),
        na=False
    )

]

# %%
filtered_df["Category"].unique()
# Out:
# <ArrowStringArray>
# [             'BEAUTY', 'BOOKS_AND_REFERENCE',            'BUSINESS',
#               'DATING',           'EDUCATION',       'ENTERTAINMENT',
#               'EVENTS',             'FINANCE',      'FOOD_AND_DRINK',
#   'HEALTH_AND_FITNESS',      'HOUSE_AND_HOME',  'LIBRARIES_AND_DEMO',
#            'LIFESTYLE',              'FAMILY',             'MEDICAL',
#          'PHOTOGRAPHY',    'TRAVEL_AND_LOCAL',               'TOOLS',
#      'PERSONALIZATION',        'PRODUCTIVITY',           'PARENTING',
#              'WEATHER',       'VIDEO_PLAYERS',  'NEWS_AND_MAGAZINES',
#  'MAPS_AND_NAVIGATION']
# Length: 25, dtype: str

# %%
category_installs = filtered_df.groupby("Category")["Installs_Num"].sum()

# %%
category_installs = category_installs.reset_index()

# %%
category_installs.head()
# Out:
#               Category  Installs_Num
# 0               BEAUTY  6.731000e+08
# 1  BOOKS_AND_REFERENCE  8.194400e+10
# 2             BUSINESS  2.281600e+10
# 3               DATING  1.024380e+10
# 4            EDUCATION  1.100044e+11

# %%
filtered_df["Installs_Num"].head()
# Out:
# 1151    500000.0
# 1152    500000.0
# 1153    500000.0
# 1154    500000.0
# 1155    500000.0
# Name: Installs_Num, dtype: float64

# %%
filtered_df["Installs_Num"].dtype
# Out:
# dtype('float64')

# %%
filtered_df["Installs_Num"].max()
# Out:
# np.float64(1000000000.0)

# %%
print(play_store_df.shape)
print(reviews_df.shape)
print(merged_df.shape)
# Out:
# (10840, 14)
# (64295, 5)
# (122662, 18)

# %%
category_installs = filtered_df.groupby("Category")["Installs_Num"].sum()

# %%
category_installs = (
    filtered_df.groupby("Category")["Installs_Num"].sum().reset_index()
)

# %%
category_installs.head()
# Out:
#               Category  Installs_Num
# 0               BEAUTY  6.731000e+08
# 1  BOOKS_AND_REFERENCE  8.194400e+10
# 2             BUSINESS  2.281600e+10
# 3               DATING  1.024380e+10
# 4            EDUCATION  1.100044e+11

# %%
filtered_df.head()
# Out:
#                                                     App Category  Rating  \
# 1151  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 1152  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 1153  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 1154  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
# 1155  BestCam Selfie-selfie, beauty camera, photo ed...   BEAUTY     3.9
#
#      Reviews Size  Installs  Type Price Content Rating  Genres   Last Updated  \
# 1151    1739  21M  500,000+  Free     0       Everyone  Beauty  July 12, 2018
# 1152    1739  21M  500,000+  Free     0       Everyone  Beauty  July 12, 2018
# 1153    1739  21M  500,000+  Free     0       Everyone  Beauty  July 12, 2018
# 1154    1739  21M  500,000+  Free     0       Everyone  Beauty  July 12, 2018
# 1155    1739  21M  500,000+  Free     0       Everyone  Beauty  July 12, 2018
#
#      Current Ver   Android Ver  Installs_Num  \
# 1151       1.0.6  4.0.3 and up      500000.0
# 1152       1.0.6  4.0.3 and up      500000.0
# 1153       1.0.6  4.0.3 and up      500000.0
# 1154       1.0.6  4.0.3 and up      500000.0
# 1155       1.0.6  4.0.3 and up      500000.0
#
#                                       Translated_Review Sentiment  \
# 1151  This a̸p̸p̸ Na Kare please Mere Bhai A L pleas...  Negative
# 1152                           Worst lot add; time west  Negative
# 1153                        bed bakvas time west stupid  Negative
# 1154                          It bad dont install worst  Negative
# 1155                     Fake install best sweet selfie  Positive
#
#       Sentiment_Polarity  Sentiment_Subjectivity
# 1151           -0.500000                0.950000
# 1152           -1.000000                1.000000
# 1153           -0.800000                1.000000
# 1154           -0.850000                0.833333
# 1155            0.283333                0.650000

# %%
filtered_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Installs_Num', 'Translated_Review', 'Sentiment',
#        'Sentiment_Polarity', 'Sentiment_Subjectivity'],
#       dtype='str')

# %%
#remove duplicates
filtered_df = filtered_df.drop_duplicates(subset=["App"])
filtered_df.shape
# Out:
# (787, 18)

# %%
category_installs = filtered_df.groupby(
    "Category"
)["Installs_Num"].sum().reset_index()

# %%
category_installs
# Out:
#                Category  Installs_Num
# 0                BEAUTY  1.320000e+07
# 1   BOOKS_AND_REFERENCE  1.273200e+09
# 2              BUSINESS  1.733000e+08
# 3                DATING  7.414600e+07
# 4             EDUCATION  1.771100e+08
# 5         ENTERTAINMENT  1.271450e+09
# 6                EVENTS  2.410000e+06
# 7                FAMILY  1.902470e+09
# 8               FINANCE  2.076600e+08
# 9        FOOD_AND_DRINK  5.655000e+07
# 10   HEALTH_AND_FITNESS  2.133000e+08
# 11       HOUSE_AND_HOME  3.026000e+07
# 12   LIBRARIES_AND_DEMO  2.795000e+07
# 13            LIFESTYLE  9.957000e+07
# 14  MAPS_AND_NAVIGATION  7.700000e+07
# 15              MEDICAL  1.900700e+07
# 16   NEWS_AND_MAGAZINES  1.617300e+09
# 17            PARENTING  7.300000e+06
# 18      PERSONALIZATION  6.797100e+08
# 19          PHOTOGRAPHY  1.819100e+09
# 20         PRODUCTIVITY  3.705600e+09
# 21                TOOLS  3.182800e+09
# 22     TRAVEL_AND_LOCAL  1.430000e+09
# 23        VIDEO_PLAYERS  1.094000e+09
# 24              WEATHER  1.170000e+08

# %%
top5_categories = category_installs.sort_values(
    by="Installs_Num",
    ascending=False
).head(5)

# %%
top5_categories
# Out:
#               Category  Installs_Num
# 20        PRODUCTIVITY  3.705600e+09
# 21               TOOLS  3.182800e+09
# 7               FAMILY  1.902470e+09
# 19         PHOTOGRAPHY  1.819100e+09
# 16  NEWS_AND_MAGAZINES  1.617300e+09

# %%
top5_categories["Highlight"] = top5_categories["Installs_Num"] > 1000000
top5_categories
# Out:
#               Category  Installs_Num  Highlight
# 20        PRODUCTIVITY  3.705600e+09       True
# 21               TOOLS  3.182800e+09       True
# 7               FAMILY  1.902470e+09       True
# 19         PHOTOGRAPHY  1.819100e+09       True
# 16  NEWS_AND_MAGAZINES  1.617300e+09       True

# %%
top5_categories
# Out:
#               Category  Installs_Num  Highlight
# 20        PRODUCTIVITY  3.705600e+09       True
# 21               TOOLS  3.182800e+09       True
# 7               FAMILY  1.902470e+09       True
# 19         PHOTOGRAPHY  1.819100e+09       True
# 16  NEWS_AND_MAGAZINES  1.617300e+09       True

# %%
category_installs
# Out:
#                Category  Installs_Num
# 0                BEAUTY  1.320000e+07
# 1   BOOKS_AND_REFERENCE  1.273200e+09
# 2              BUSINESS  1.733000e+08
# 3                DATING  7.414600e+07
# 4             EDUCATION  1.771100e+08
# 5         ENTERTAINMENT  1.271450e+09
# 6                EVENTS  2.410000e+06
# 7                FAMILY  1.902470e+09
# 8               FINANCE  2.076600e+08
# 9        FOOD_AND_DRINK  5.655000e+07
# 10   HEALTH_AND_FITNESS  2.133000e+08
# 11       HOUSE_AND_HOME  3.026000e+07
# 12   LIBRARIES_AND_DEMO  2.795000e+07
# 13            LIFESTYLE  9.957000e+07
# 14  MAPS_AND_NAVIGATION  7.700000e+07
# 15              MEDICAL  1.900700e+07
# 16   NEWS_AND_MAGAZINES  1.617300e+09
# 17            PARENTING  7.300000e+06
# 18      PERSONALIZATION  6.797100e+08
# 19          PHOTOGRAPHY  1.819100e+09
# 20         PRODUCTIVITY  3.705600e+09
# 21                TOOLS  3.182800e+09
# 22     TRAVEL_AND_LOCAL  1.430000e+09
# 23        VIDEO_PLAYERS  1.094000e+09
# 24              WEATHER  1.170000e+08

# %%
top5_categories["Country"] = [
    "India",
    "United States",
    "Germany",
    "Japan",
    "Australia"
]

# %%
top5_categories
# Out:
#               Category  Installs_Num  Highlight        Country
# 20        PRODUCTIVITY  3.705600e+09       True          India
# 21               TOOLS  3.182800e+09       True  United States
# 7               FAMILY  1.902470e+09       True        Germany
# 19         PHOTOGRAPHY  1.819100e+09       True          Japan
# 16  NEWS_AND_MAGAZINES  1.617300e+09       True      Australia

# %%
import plotly.express as px

fig = px.choropleth(
    top5_categories,
    locations="Country",
    locationmode="country names",
    color="Installs_Num",
    hover_name="Category",
    title="Global Installs by Top 5 App Categories"
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21284\2164619895.py:3: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(

# %%
fig.show()

# %%
from datetime import datetime

current_hour = datetime.now().hour

print(current_hour)
# Out:
# 18

# %%
if 18 <= current_hour < 20:
    fig.show()
else:
    print("Choropleth Map is available only between 6 PM IST and 8 PM IST.")

# %%
current_hour = 18

# %%
if 18 <= current_hour < 20:
    fig.show()
else:
    print("Choropleth Map is available only between 6 PM IST and 8 PM IST.")
